# %%
import pandas as pd

# %%
import numpy as np

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# # Load Data - Coverage

# %%
df_coverage = pd.read_excel(r"C:\Users\Harish\Desktop\GUVI\SecondProject_VaccinationAnalysis\Data\coverage-data.xlsx")

# %%
df_coverage
# Out:
#                                 GROUP CODE                    NAME    YEAR  \
# 0                           COUNTRIES  ABW                   Aruba  2023.0
# 1                           COUNTRIES  ABW                   Aruba  2023.0
# 2                           COUNTRIES  ABW                   Aruba  2023.0
# 3                           COUNTRIES  ABW                   Aruba  2023.0
# 4                           COUNTRIES  ABW                   Aruba  2023.0
# ...                               ...  ...                     ...     ...
# 399854                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399855                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399856                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399857                    WHO_REGIONS  WPR  Western Pacific Region  1980.0
# 399858  Created: 2025-02-01 16:00 UTC  NaN                     NaN     NaN
#
# ...

# %%
df_coverage = df_coverage.drop('COVERAGE_CATEGORY_DESCRIPTION', axis = 1)

# %%
df_coverage = df_coverage.rename(columns={'COVERAGE': 'COVERAGE_PERCENTAGE'})

# %%
df_coverage
# Out:
#               GROUP CODE                    NAME    YEAR  ANTIGEN  \
# 0         COUNTRIES  ABW                   Aruba  2023.0      BCG
# 1         COUNTRIES  ABW                   Aruba  2023.0      BCG
# 2         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV4
# 3         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV4
# 4         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV5
# ...             ...  ...                     ...     ...      ...
# 399853  WHO_REGIONS  WPR  Western Pacific Region  1980.0   DTPCV3
# 399854  WHO_REGIONS  WPR  Western Pacific Region  1980.0     MCV1
# 399855  WHO_REGIONS  WPR  Western Pacific Region  1980.0      PAB
# 399856  WHO_REGIONS  WPR  Western Pacific Region  1980.0     POL3
# 399857  WHO_REGIONS  WPR  Western Pacific Region  1980.0     RCV1
#
#                                       ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0                                                     BCG             ADMIN
# ...

# %%
duplicate_rows = df_coverage.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
df_coverage.shape
# Out:
# (399859, 10)

# %%
df_coverage.isnull().sum()
# Out:
# GROUP                       0
# CODE                        0
# NAME                     1274
# YEAR                        0
# ANTIGEN                     0
# ANTIGEN_DESCRIPTION         0
# COVERAGE_CATEGORY           0
# TARGET_NUMBER          320828
# DOSES                  320531
# COVERAGE_PERCENTAGE    169381
# dtype: int64

# %%
df_coverage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 399858 entries, 0 to 399857
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   GROUP                399858 non-null  object
#  1   CODE                 399858 non-null  object
#  2   NAME                 398584 non-null  object
#  3   YEAR                 399858 non-null  float64
#  4   ANTIGEN              399858 non-null  object
#  5   ANTIGEN_DESCRIPTION  399858 non-null  object
#  6   COVERAGE_CATEGORY    399858 non-null  object
#  7   TARGET_NUMBER        79030 non-null   float64
#  8   DOSES                79327 non-null   float64
#  9   COVERAGE_PERCENTAGE  230477 non-null  float64
# dtypes: float64(4), object(6)
# memory usage: 33.6+ MB

# %%
rows_with_nulls = df_coverage[df_coverage.isnull().any(axis=1)] 
print(rows_with_nulls)
# Out:
#                                 GROUP CODE             NAME    YEAR  ANTIGEN  \
# 0                           COUNTRIES  ABW            Aruba  2023.0      BCG
# 1                           COUNTRIES  ABW            Aruba  2023.0      BCG
# 3                           COUNTRIES  ABW            Aruba  2023.0  DIPHCV4
# 5                           COUNTRIES  ABW            Aruba  2023.0  DIPHCV5
# 7                           COUNTRIES  ABW            Aruba  2023.0  DIPHCV6
# ...                               ...  ...              ...     ...      ...
# 398614                    WHO_REGIONS  EUR  European Region  1983.0      PAB
# 398621                    WHO_REGIONS  EUR  European Region  1982.0      PAB
# 398628                    WHO_REGIONS  EUR  European Region  1981.0      PAB
# 398635                    WHO_REGIONS  EUR  European Region  1980.0      PAB
# 399858  Created: 2025-02-01 16:00 UTC  NaN              NaN     NaN      NaN
#
# ...

# %%
null_values_in_Name = df_coverage[df_coverage['NAME'].isnull()]
print(null_values_in_Name)
# Out:
#                                 GROUP         CODE NAME    YEAR   ANTIGEN  \
# 392263                        WB_LONG   WB_LONG_NA  NaN  2023.0  15HPV1_F
# 392264                        WB_LONG   WB_LONG_NA  NaN  2023.0  15HPV1_M
# 392265                        WB_LONG   WB_LONG_NA  NaN  2023.0  15HPVC_F
# 392266                        WB_LONG   WB_LONG_NA  NaN  2023.0  15HPVC_M
# 392267                        WB_LONG   WB_LONG_NA  NaN  2023.0       BCG
# ...                               ...          ...  ...     ...       ...
# 396097                       WB_SHORT  WB_SHORT_NA  NaN  1980.0      MCV1
# 396098                       WB_SHORT  WB_SHORT_NA  NaN  1980.0       PAB
# 396099                       WB_SHORT  WB_SHORT_NA  NaN  1980.0      POL3
# 396100                       WB_SHORT  WB_SHORT_NA  NaN  1980.0      RCV1
# 399858  Created: 2025-02-01 16:00 UTC          NaN  NaN     NaN       NaN
#
#                                       ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# ...

# %%
df_coverage[df_coverage['CODE'].isnull()]
# Out:
#                                 GROUP CODE NAME  YEAR ANTIGEN  \
# 399858  Created: 2025-02-01 16:00 UTC  NaN  NaN   NaN     NaN
#
#        ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  TARGET_NUMBER  DOSES  COVERAGE
# 399858                 NaN               NaN            NaN    NaN       NaN

# %%
df_coverage[~df_coverage['CODE'].isnull()]
# Out:
#               GROUP CODE                    NAME    YEAR  ANTIGEN  \
# 0         COUNTRIES  ABW                   Aruba  2023.0      BCG
# 1         COUNTRIES  ABW                   Aruba  2023.0      BCG
# 2         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV4
# 3         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV4
# 4         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV5
# ...             ...  ...                     ...     ...      ...
# 399853  WHO_REGIONS  WPR  Western Pacific Region  1980.0   DTPCV3
# 399854  WHO_REGIONS  WPR  Western Pacific Region  1980.0     MCV1
# 399855  WHO_REGIONS  WPR  Western Pacific Region  1980.0      PAB
# 399856  WHO_REGIONS  WPR  Western Pacific Region  1980.0     POL3
# 399857  WHO_REGIONS  WPR  Western Pacific Region  1980.0     RCV1
#
#                                       ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0                                                     BCG             ADMIN
# ...

# %%
df_coverage = df_coverage[~df_coverage['CODE'].isnull()]

# %%
df_coverage
# Out:
#               GROUP CODE                    NAME    YEAR  ANTIGEN  \
# 0         COUNTRIES  ABW                   Aruba  2023.0      BCG
# 1         COUNTRIES  ABW                   Aruba  2023.0      BCG
# 2         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV4
# 3         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV4
# 4         COUNTRIES  ABW                   Aruba  2023.0  DIPHCV5
# ...             ...  ...                     ...     ...      ...
# 399853  WHO_REGIONS  WPR  Western Pacific Region  1980.0   DTPCV3
# 399854  WHO_REGIONS  WPR  Western Pacific Region  1980.0     MCV1
# 399855  WHO_REGIONS  WPR  Western Pacific Region  1980.0      PAB
# 399856  WHO_REGIONS  WPR  Western Pacific Region  1980.0     POL3
# 399857  WHO_REGIONS  WPR  Western Pacific Region  1980.0     RCV1
#
#                                       ANTIGEN_DESCRIPTION COVERAGE_CATEGORY  \
# 0                                                     BCG             ADMIN
# ...

# %% [markdown]
# # Load Data - Incidence Rate

# %%
df_incidence = pd.read_excel(r"C:\Users\Harish\Desktop\GUVI\SecondProject_VaccinationAnalysis\Data\incidence-rate-data.xlsx")

# %%
df_incidence
# Out:
#                                GROUP CODE      NAME    YEAR          DISEASE  \
# 0                          COUNTRIES  ABW     Aruba  2023.0              CRS
# 1                          COUNTRIES  ABW     Aruba  2023.0       DIPHTHERIA
# 2                          COUNTRIES  ABW     Aruba  2023.0  INVASIVE_MENING
# 3                          COUNTRIES  ABW     Aruba  2023.0          MEASLES
# 4                          COUNTRIES  ABW     Aruba  2023.0            MUMPS
# ...                              ...  ...       ...     ...              ...
# 84941                      COUNTRIES  ZWE  Zimbabwe  1980.0        PERTUSSIS
# 84942                      COUNTRIES  ZWE  Zimbabwe  1980.0            POLIO
# 84943                      COUNTRIES  ZWE  Zimbabwe  1980.0         TTETANUS
# 84944                      COUNTRIES  ZWE  Zimbabwe  1980.0           YFEVER
# 84945  Created: 2025-02-01 16:03 UTC  NaN       NaN     NaN              NaN
#
# ...

# %%
duplicate_rows = df_incidence.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
df_incidence.shape
# Out:
# (84946, 8)

# %%
df_incidence.isnull().sum()
# Out:
# GROUP                      0
# CODE                       1
# NAME                       1
# YEAR                       1
# DISEASE                    1
# DISEASE_DESCRIPTION        1
# DENOMINATOR                1
# INCIDENCE_RATE         23362
# dtype: int64

# %%
df_incidence = df_incidence[~df_incidence['CODE'].isnull()]

# %%
df_incidence
# Out:
#            GROUP CODE      NAME    YEAR          DISEASE  \
# 0      COUNTRIES  ABW     Aruba  2023.0              CRS
# 1      COUNTRIES  ABW     Aruba  2023.0       DIPHTHERIA
# 2      COUNTRIES  ABW     Aruba  2023.0  INVASIVE_MENING
# 3      COUNTRIES  ABW     Aruba  2023.0          MEASLES
# 4      COUNTRIES  ABW     Aruba  2023.0            MUMPS
# ...          ...  ...       ...     ...              ...
# 84940  COUNTRIES  ZWE  Zimbabwe  1980.0         NTETANUS
# 84941  COUNTRIES  ZWE  Zimbabwe  1980.0        PERTUSSIS
# 84942  COUNTRIES  ZWE  Zimbabwe  1980.0            POLIO
# 84943  COUNTRIES  ZWE  Zimbabwe  1980.0         TTETANUS
# 84944  COUNTRIES  ZWE  Zimbabwe  1980.0           YFEVER
#
#                   DISEASE_DESCRIPTION                     DENOMINATOR  \
# 0         Congenital rubella syndrome          per 10,000 live births
# 1                          Diphtheria  per 1,000,000 total population
# ...

# %%
df_incidence.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84945 entries, 0 to 84944
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GROUP                84945 non-null  object
#  1   CODE                 84945 non-null  object
#  2   NAME                 84945 non-null  object
#  3   YEAR                 84945 non-null  float64
#  4   DISEASE              84945 non-null  object
#  5   DISEASE_DESCRIPTION  84945 non-null  object
#  6   DENOMINATOR          84945 non-null  object
#  7   INCIDENCE_RATE       61584 non-null  float64
# dtypes: float64(2), object(6)
# memory usage: 5.8+ MB

# %% [markdown]
# # Load Data - Reported Cases

# %%
df_reported = pd.read_excel(r"C:\Users\Harish\Desktop\GUVI\SecondProject_VaccinationAnalysis\Data\reported-cases-data.xlsx")

# %%
df_reported
# Out:
#                                GROUP CODE      NAME    YEAR          DISEASE  \
# 0                          COUNTRIES  ABW     Aruba  2023.0              CRS
# 1                          COUNTRIES  ABW     Aruba  2023.0       DIPHTHERIA
# 2                          COUNTRIES  ABW     Aruba  2023.0  INVASIVE_MENING
# 3                          COUNTRIES  ABW     Aruba  2023.0          MEASLES
# 4                          COUNTRIES  ABW     Aruba  2023.0            MUMPS
# ...                              ...  ...       ...     ...              ...
# 84865                      COUNTRIES  ZWE  Zimbabwe  1980.0        PERTUSSIS
# 84866                      COUNTRIES  ZWE  Zimbabwe  1980.0            POLIO
# 84867                      COUNTRIES  ZWE  Zimbabwe  1980.0         TTETANUS
# 84868                      COUNTRIES  ZWE  Zimbabwe  1980.0           YFEVER
# 84869  Created: 2025-02-01 16:02 UTC  NaN       NaN     NaN              NaN
#
# ...

# %%
duplicate_rows = df_reported.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
df_reported.isnull().sum()
# Out:
# GROUP                      0
# CODE                       1
# NAME                       1
# YEAR                       1
# DISEASE                    1
# DISEASE_DESCRIPTION        1
# CASES                  19400
# dtype: int64

# %%
df_reported = df_reported[~df_reported['CODE'].isnull()]

# %%
df_reported
# Out:
#            GROUP CODE      NAME    YEAR          DISEASE  \
# 0      COUNTRIES  ABW     Aruba  2023.0              CRS
# 1      COUNTRIES  ABW     Aruba  2023.0       DIPHTHERIA
# 2      COUNTRIES  ABW     Aruba  2023.0  INVASIVE_MENING
# 3      COUNTRIES  ABW     Aruba  2023.0          MEASLES
# 4      COUNTRIES  ABW     Aruba  2023.0            MUMPS
# ...          ...  ...       ...     ...              ...
# 84864  COUNTRIES  ZWE  Zimbabwe  1980.0         NTETANUS
# 84865  COUNTRIES  ZWE  Zimbabwe  1980.0        PERTUSSIS
# 84866  COUNTRIES  ZWE  Zimbabwe  1980.0            POLIO
# 84867  COUNTRIES  ZWE  Zimbabwe  1980.0         TTETANUS
# 84868  COUNTRIES  ZWE  Zimbabwe  1980.0           YFEVER
#
#                   DISEASE_DESCRIPTION   CASES
# 0         Congenital rubella syndrome     0.0
# 1                          Diphtheria     0.0
# 2      Invasive meningococcal disease     1.0
# 3                             Measles     NaN
# ...

# %%
df_reported.isnull().sum()
# Out:
# GROUP                      0
# CODE                       0
# NAME                       0
# YEAR                       0
# DISEASE                    0
# DISEASE_DESCRIPTION        0
# CASES                  19399
# dtype: int64

# %%
df_reported.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84869 entries, 0 to 84868
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   GROUP                84869 non-null  object
#  1   CODE                 84869 non-null  object
#  2   NAME                 84869 non-null  object
#  3   YEAR                 84869 non-null  float64
#  4   DISEASE              84869 non-null  object
#  5   DISEASE_DESCRIPTION  84869 non-null  object
#  6   CASES                65470 non-null  float64
# dtypes: float64(2), object(5)
# memory usage: 5.2+ MB

# %% [markdown]
# # Load Data - Vaccine Introduction

# %%
df_vacintro = pd.read_excel(r"C:\Users\Harish\Desktop\GUVI\SecondProject_VaccinationAnalysis\Data\vaccine-introduction-data.xlsx")

# %%
df_vacintro
# Out:
#                            ISO_3_CODE  COUNTRYNAME WHO_REGION    YEAR  \
# 0                                 AFG  Afghanistan       EMRO  2023.0
# 1                                 AFG  Afghanistan       EMRO  2023.0
# 2                                 AFG  Afghanistan       EMRO  2023.0
# 3                                 AFG  Afghanistan       EMRO  2023.0
# 4                                 AFG  Afghanistan       EMRO  2023.0
# ...                               ...          ...        ...     ...
# 138316                            ZWE     Zimbabwe       AFRO  1943.0
# 138317                            ZWE     Zimbabwe       AFRO  1942.0
# 138318                            ZWE     Zimbabwe       AFRO  1941.0
# 138319                            ZWE     Zimbabwe       AFRO  1940.0
# 138320  Created: 2025-02-01 07:09 UTC          NaN        NaN     NaN
#
#                                         DESCRIPTION INTRO
# 0                  aP (acellular pertussis) vaccine    No
# ...

# %%
duplicate_rows = df_vacintro.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
df_vacintro.isnull().sum()
# Out:
# ISO_3_CODE     0
# COUNTRYNAME    1
# WHO_REGION     1
# YEAR           1
# DESCRIPTION    1
# INTRO          1
# dtype: int64

# %%
df_vacintro = df_vacintro[~df_vacintro['COUNTRYNAME'].isnull()]

# %%
df_vacintro.isnull().sum()
# Out:
# ISO_3_CODE     0
# COUNTRYNAME    0
# WHO_REGION     0
# YEAR           0
# DESCRIPTION    0
# INTRO          0
# dtype: int64

# %%
df_vacintro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138320 entries, 0 to 138319
# Data columns (total 6 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   ISO_3_CODE   138320 non-null  object
#  1   COUNTRYNAME  138320 non-null  object
#  2   WHO_REGION   138320 non-null  object
#  3   YEAR         138320 non-null  float64
#  4   DESCRIPTION  138320 non-null  object
#  5   INTRO        138320 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 7.4+ MB

# %% [markdown]
# # Load Data - Vaccine Schedule

# %%
df_vacsch = pd.read_excel(r"C:\Users\Harish\Desktop\GUVI\SecondProject_VaccinationAnalysis\Data\vaccine-schedule-data.xlsx")

# %%
df_vacsch
# Out:
#                          ISO_3_CODE COUNTRYNAME WHO_REGION    YEAR  \
# 0                               ABW       Aruba       AMRO  2023.0
# 1                               ABW       Aruba       AMRO  2023.0
# 2                               ABW       Aruba       AMRO  2023.0
# 3                               ABW       Aruba       AMRO  2023.0
# 4                               ABW       Aruba       AMRO  2023.0
# ...                             ...         ...        ...     ...
# 8048                            ZWE    Zimbabwe       AFRO  2023.0
# 8049                            ZWE    Zimbabwe       AFRO  2023.0
# 8050                            ZWE    Zimbabwe       AFRO  2023.0
# 8051                            ZWE    Zimbabwe       AFRO  2023.0
# 8052  Created: 2025-02-01 16:10 UTC         NaN        NaN     NaN
#
#      VACCINECODE               VACCINE_DESCRIPTION  SCHEDULEROUNDS  TARGETPOP  \
# 0     DTAPHIBIPV  DTaP-Hib-IPV (acellular) vaccine             1.0        NaN
# ...

# %%
duplicate_rows = df_vacsch.duplicated()
print("Number of duplicate rows:", duplicate_rows.sum())
# Out:
# Number of duplicate rows: 0

# %%
df_vacsch.isnull().sum()
# Out:
# ISO_3_CODE                  0
# COUNTRYNAME                 1
# WHO_REGION                  1
# YEAR                        1
# VACCINECODE                 1
# VACCINE_DESCRIPTION         1
# SCHEDULEROUNDS              1
# TARGETPOP                4258
# TARGETPOP_DESCRIPTION       1
# GEOAREA                    31
# AGEADMINISTERED          1046
# SOURCECOMMENT            2914
# dtype: int64

# %%
df_vacsch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8053 entries, 0 to 8052
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ISO_3_CODE             8053 non-null   object
#  1   COUNTRYNAME            8052 non-null   object
#  2   WHO_REGION             8052 non-null   object
#  3   YEAR                   8052 non-null   float64
#  4   VACCINECODE            8052 non-null   object
#  5   VACCINE_DESCRIPTION    8052 non-null   object
#  6   SCHEDULEROUNDS         8052 non-null   float64
#  7   TARGETPOP              3795 non-null   object
#  8   TARGETPOP_DESCRIPTION  8052 non-null   object
#  9   GEOAREA                8022 non-null   object
#  10  AGEADMINISTERED        7007 non-null   object
#  11  SOURCECOMMENT          5139 non-null   object
# dtypes: float64(2), object(10)
# memory usage: 755.1+ KB

# %%
df_vacsch[df_vacsch['GEOAREA'].isnull()]
# Out:
#                          ISO_3_CODE               COUNTRYNAME WHO_REGION  \
# 837                             BIH    Bosnia and Herzegovina       EURO
# 1534                            CMR                  Cameroon       AFRO
# 1607                            COK              Cook Islands       WPRO
# 1608                            COK              Cook Islands       WPRO
# 1609                            COK              Cook Islands       WPRO
# 1610                            COK              Cook Islands       WPRO
# 1611                            COK              Cook Islands       WPRO
# 2922                            GNQ         Equatorial Guinea       AFRO
# 2945                            GNQ         Equatorial Guinea       AFRO
# 2946                            GNQ         Equatorial Guinea       AFRO
# 3609                            ISL                   Iceland       EURO
# 3610                            ISL                   Iceland       EURO
# ...

# %%
df_vacsch = df_vacsch[~df_vacsch['COUNTRYNAME'].isnull()]

# %%
df_vacsch.isnull().sum()
# Out:
# ISO_3_CODE                  0
# COUNTRYNAME                 0
# WHO_REGION                  0
# YEAR                        0
# VACCINECODE                 0
# VACCINE_DESCRIPTION         0
# SCHEDULEROUNDS              0
# TARGETPOP                4257
# TARGETPOP_DESCRIPTION       0
# GEOAREA                    30
# AGEADMINISTERED          1045
# SOURCECOMMENT            2913
# dtype: int64

# %% [markdown]
# # Load Data into MySQL Database

# %%
import mysql.connector
from getpass import getpass # helps to securely transfer password
from mysql.connector import connect, Error

try:
    with connect(
        host = "localhost",
        user = input("Enter username"),         # root
        password = getpass("Enter password: "), # get the encrypted password
    ) as connection:
        print(connection)
except Error as e:
    print(e)
# Out:
# Enter username root
# Enter password:  ········
# ...

# %%
connection.reconnect()

# %%
create_new_db = "CREATE DATABASE IF NOT EXISTS WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(create_new_db)

# %%
show_db_query = "SHOW DATABASES"

try:
    with connect(
        host="localhost",
        user=input("Enter username: "),
        password=getpass("Enter password: "),
    ) as connection:
         with connection.cursor() as cursor:
            cursor.execute(show_db_query)
            print("\n")
            for db in cursor:
                print(db)

except Error as e:
    print(e)
# Out:
# Enter username:  root
# Enter password:  ········
# ('expense_database',)
# ('information_schema',)
# ('mysql',)
# ('online_movie_rating',)
# ('performance_schema',)
# ('sailors',)
# ('sakila',)
# ('sample_database',)
# ('sys',)
# ('who_vaccination',)
# ('world',)

# %%
connection.reconnect()

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)
    
create_new_table = """
CREATE TABLE coverage
    (
    `Group` VARCHAR(100),
    Code VARCHAR(100),
    Name VARCHAR(100),
    Year FLOAT,
    Antigen VARCHAR(100),
    Antigen_Description VARCHAR(100), 
    Coverage_Category VARCHAR(100),
    Target_Number FLOAT,
    Doses FLOAT,
    Coverage_Percentage FLOAT
    )
"""
with connection.cursor() as cursor:
    cursor.execute(create_new_table)

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+mysqlconnector://root:123456789@localhost/WHO_Vaccination")

# %%
df_coverage.to_sql('coverage', con=engine, if_exists='append', index=False)
# Out:
# 399858

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)
    
create_new_table = """
CREATE TABLE incidence
    (
    `Group` VARCHAR(100),
    Code VARCHAR(100),
    Name VARCHAR(100),
    Year FLOAT,
    Disease VARCHAR(100),
    Disease_Description VARCHAR(100), 
    Denominator VARCHAR(100),
    Incidence_Rate FLOAT
    )
"""
with connection.cursor() as cursor:
    cursor.execute(create_new_table)

# %%
df_incidence.to_sql('incidence', con=engine, if_exists='append', index=False)
# Out:
# 84945

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)
    
create_new_table = """
CREATE TABLE reported
    (
    `Group` VARCHAR(100),
    Code VARCHAR(100),
    Name VARCHAR(100),
    Year FLOAT,
    Disease VARCHAR(100),
    Disease_Description VARCHAR(100), 
    Cases FLOAT
    )
"""
with connection.cursor() as cursor:
    cursor.execute(create_new_table)

# %%
df_reported.to_sql('reported', con=engine, if_exists='append', index=False)
# Out:
# 84869

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)
    
create_new_table = """
CREATE TABLE vacintro
    (
    ISO_3_CODE VARCHAR(100),
    COUNTRYNAME VARCHAR(100),
    WHO_REGION VARCHAR(100),
    Year FLOAT,
    DESCRIPTION VARCHAR(100),
    INTRO VARCHAR(20)
    )
"""
with connection.cursor() as cursor:
    cursor.execute(create_new_table)

# %%
df_vacintro.to_sql('vacintro', con=engine, if_exists='append', index=False)
# Out:
# 138320

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)
    
create_new_table = """
CREATE TABLE vacsch
    (
    ISO_3_CODE VARCHAR(100),
    COUNTRYNAME VARCHAR(100),
    WHO_REGION VARCHAR(100),
    Year FLOAT,
    VACCINECODE VARCHAR(100),
    VACCINE_DESCRIPTION VARCHAR(100),
    SCHEDULEROUNDS FLOAT,
    TARGETPOP VARCHAR(50),
    TARGETPOP_DESCRIPTION VARCHAR(50),
    GEOAREA VARCHAR(50),
    AGEADMINISTERED VARCHAR(50),
    SOURCECOMMENT VARCHAR(200)
    )
"""
with connection.cursor() as cursor:
    cursor.execute(create_new_table)

# %%
alter_table_query = """
    ALTER TABLE vacsch  
    MODIFY SOURCECOMMENT 
    VARCHAR(2000)
"""

with connection.cursor() as cursor:
    cursor.execute(alter_table_query)

# %%
df_vacsch.to_sql('vacsch', con=engine, if_exists='append', index=False)
# Out:
# 8052

# %% [markdown]
# # Normalization
#
# To create 3 Tables regioncode with columns (Group, Code, Name) , dieases (Disease, Disease_description), who_region(ISO_3_CODE,COUNTRYNAME,WHO_REGION).

# %%
import mysql.connector
from getpass import getpass # helps to securely transfer password
from mysql.connector import connect, Error

try:
    with connect(
        host = "localhost",
        user = input("Enter username"),         # root
        password = getpass("Enter password: "), # get the encrypted password
    ) as connection:
        print(connection)
except Error as e:
    print(e)
# Out:
# Enter username root
# Enter password:  ········
# ...

# %%
connection.reconnect()

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

Distinct_Columns_query = """
SELECT DISTINCT `group`,Code,Name FROM coverage 
"""

with connection.cursor() as cursor:
    cursor.execute(Distinct_Columns_query)
    result = cursor.fetchall()
    for row in result:
        print(row)
# Out:
# ('COUNTRIES', 'ABW', 'Aruba')
# ('COUNTRIES', 'AFG', 'Afghanistan')
# ('WHO_REGIONS', 'AFR', 'African Region')
# ('COUNTRIES', 'AGO', 'Angola')
# ('COUNTRIES', 'AIA', 'Anguilla')
# ('COUNTRIES', 'ALB', 'Albania')
# ('WHO_REGIONS', 'AMR', 'Region of the Americas')
# ('COUNTRIES', 'AND', 'Andorra')
# ('COUNTRIES', 'ARE', 'United Arab Emirates')
# ('COUNTRIES', 'ARG', 'Argentina')
# ('COUNTRIES', 'ARM', 'Armenia')
# ('COUNTRIES', 'ASM', 'American Samoa')
# ('COUNTRIES', 'ATG', 'Antigua and Barbuda')
# ('COUNTRIES', 'AUS', 'Australia')
# ('COUNTRIES', 'AUT', 'Austria')
# ('COUNTRIES', 'AZE', 'Azerbaijan')
# ('COUNTRIES', 'BDI', 'Burundi')
# ('COUNTRIES', 'BEL', 'Belgium')
# ('COUNTRIES', 'BEN', 'Benin')
# ('COUNTRIES', 'BFA', 'Burkina Faso')
# ('COUNTRIES', 'BGD', 'Bangladesh')
# ('COUNTRIES', 'BGR', 'Bulgaria')
# ('COUNTRIES', 'BHR', 'Bahrain')
# ('COUNTRIES', 'BHS', 'Bahamas')
# ('COUNTRIES', 'BIH', 'Bosnia and Herzegovina')
# ('COUNTRIES', 'BLR', 'Belarus')
# ...

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

create_new_table = """
CREATE Table regioncode As SELECT DISTINCT `group`,Code,Name FROM coverage 
"""

with connection.cursor() as cursor:
    cursor.execute(create_new_table)

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

create_new_table = """
CREATE Table diseases SELECT DISTINCT Disease,Disease_Description from incidence
"""

with connection.cursor() as cursor:
    cursor.execute(create_new_table)

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

create_new_table = """
CREATE Table WHO_region SELECT DISTINCT ISO_3_CODE,COUNTRYNAME,WHO_REGION from vacintro
"""

with connection.cursor() as cursor:
    cursor.execute(create_new_table)

# %%
List_All_Tables = """
      SELECT table_name FROM information_schema.tables WHERE table_type='BASE TABLE'
      AND table_schema = 'WHO_Vaccination' """

with connection.cursor() as cursor:
    cursor.execute(List_All_Tables)
    result = cursor.fetchall()
    for row in result:
        print(row)
# Out:
# ('coverage',)
# ('diseases',)
# ('incidence',)
# ('regioncode',)
# ('reported',)
# ('vacintro',)
# ('vacsch',)
# ('who_region',)

# %% [markdown]
# # UPDATE PRIMARY / Foregin KEYS

# %%
alter_table_query = """
    ALTER TABLE coverage ADD PRIMARY KEY (Code, year, Antigen, COVERAGE_CATEGORY)
"""

with connection.cursor() as cursor:
    cursor.execute(alter_table_query)

# %%
primary_key_query = """
    ALTER TABLE regioncode ADD PRIMARY KEY (Code)
"""
with connection.cursor() as cursor:
    cursor.execute(primary_key_query)

# %%
foreign_key_query = """
    ALTER TABLE coverage ADD FOREIGN KEY(Code) REFERENCES regioncode (Code)
"""
with connection.cursor() as cursor:
    cursor.execute(foreign_key_query)

# %%
foreign_key_query = """
    ALTER TABLE incidence ADD FOREIGN KEY(Code) REFERENCES regioncode (Code)
"""
with connection.cursor() as cursor:
    cursor.execute(foreign_key_query)

# %%
foreign_key_query = """
    ALTER TABLE reported ADD FOREIGN KEY(Code) REFERENCES regioncode (Code)
"""
with connection.cursor() as cursor:
    cursor.execute(foreign_key_query)

# %%
primary_key_query = """
    ALTER TABLE who_region ADD PRIMARY KEY(ISO_3_CODE)
"""
with connection.cursor() as cursor:
    cursor.execute(primary_key_query)

# %%
foreign_key_query = """
    ALTER TABLE vacintro ADD FOREIGN KEY(ISO_3_CODE) REFERENCES who_region (ISO_3_CODE)
"""
with connection.cursor() as cursor:
    cursor.execute(foreign_key_query)

# %%
foreign_key_query = """
    ALTER TABLE vacsch ADD FOREIGN KEY(ISO_3_CODE) REFERENCES who_region (ISO_3_CODE)
"""
with connection.cursor() as cursor:
    cursor.execute(foreign_key_query)
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~\anaconda3\envs\Guvi_DS\Lib\site-packages\mysql\connector\connection_cext.py:706, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     705         query = query.encode("utf-8")
# --> 706     self._cmysql.query(
#     707         query,
#     708         raw=raw,
#     709         buffered=buffered,
#     710         raw_as_string=raw_as_string,
#     711         query_attrs=self.query_attrs,
#     712     )
#     713 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Cannot add or update a child row: a foreign key constraint fails (`who_vaccination`.`#sql-1778_f`, CONSTRAINT `vacsch_ibfk_1` FOREIGN KEY (`ISO_3_CODE`) REFERENCES `who_region` (`ISO_3_CODE`))
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

update_table = """
INSERT INTO who_region(ISO_3_CODE,COUNTRYNAME,WHO_REGION) SELECT DISTINCT ISO_3_CODE,COUNTRYNAME,WHO_REGION from who_vaccination.vacsch where ISO_3_CODE NOT IN (SELECT ISO_3_CODE FROM who_vaccination.who_region)
"""

with connection.cursor() as cursor:
    cursor.execute(update_table)
    result = cursor.fetchall()
    for row in result:
        print(row)

# %%
foreign_key_query = """
    ALTER TABLE vacsch ADD FOREIGN KEY(ISO_3_CODE) REFERENCES who_region (ISO_3_CODE)
"""
with connection.cursor() as cursor:
    cursor.execute(foreign_key_query)

# %%
connection.close()

# %%
connection.reconnect()
select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

update_table = """
SELECT DISTINCT ISO_3_CODE,COUNTRYNAME,WHO_REGION from who_vaccination.vacsch
"""

with connection.cursor() as cursor:
    cursor.execute(update_table)
    result = cursor.fetchall()
    for row in result:
        print(row)

connection.close()
# Out:
# ('ABW', 'Aruba', 'AMRO')
# ('AFG', 'Afghanistan', 'EMRO')
# ('AGO', 'Angola', 'AFRO')
# ('AIA', 'Anguilla', 'AMRO')
# ('ALB', 'Albania', 'EURO')
# ('AND', 'Andorra', 'EURO')
# ('ARE', 'United Arab Emirates', 'EMRO')
# ('ARG', 'Argentina', 'AMRO')
# ('ARM', 'Armenia', 'EURO')
# ('ATG', 'Antigua and Barbuda', 'AMRO')
# ('AUS', 'Australia', 'WPRO')
# ('AUT', 'Austria', 'EURO')
# ('AZE', 'Azerbaijan', 'EURO')
# ('BDI', 'Burundi', 'AFRO')
# ('BEL', 'Belgium', 'EURO')
# ('BEN', 'Benin', 'AFRO')
# ('BFA', 'Burkina Faso', 'AFRO')
# ('BGD', 'Bangladesh', 'SEARO')
# ('BGR', 'Bulgaria', 'EURO')
# ('BHR', 'Bahrain', 'EMRO')
# ('BHS', 'Bahamas', 'AMRO')
# ('BIH', 'Bosnia and Herzegovina', 'EURO')
# ('BLR', 'Belarus', 'EURO')
# ('BLZ', 'Belize', 'AMRO')
# ('BMU', 'Bermuda', 'AMRO')
# ('BOL', 'Bolivia (Plurinational State of)', 'AMRO')
# ('BRA', 'Brazil', 'AMRO')
# ('BRB', 'Barbados', 'AMRO')
# ('BRN', 'Brunei Darussalam', 'WPRO')
# ('BTN', 'Bhutan', 'SEARO')
# ('BWA', 'Botswana', 'AFRO')
# ...

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

primary_key_query = """
    ALTER TABLE diseases ADD PRIMARY KEY (Disease)
"""
with connection.cursor() as cursor:
    cursor.execute(primary_key_query)
connection.close()

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

foreign_key_query = """
    ALTER TABLE incidence ADD FOREIGN KEY(Disease) REFERENCES diseases(Disease)
"""
with connection.cursor() as cursor:
    cursor.execute(foreign_key_query)
    
connection.close()

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

foreign_key_query = """
    ALTER TABLE reported ADD FOREIGN KEY(Disease) REFERENCES diseases(Disease)
"""
with connection.cursor() as cursor:
    cursor.execute(foreign_key_query)
    
connection.close()

# %% [markdown]
# # Drop Duplicate Columns from the Tables, as Foreign Key has been established;
#
# Drop Columns Group, Name from Tables coverage, incidence, reported - Foreign Key enabled to regioncode table;
#
# Drop Columns Disease_Description from Tables incidence, reported - Foreign Key enabled to diseases table;
#
# Drop Columns COUNTRYNAME, WHO_REGION from tables vacsch and vacintro - Foreign Key enabled to WHO_region table.

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

drop_column_query = """
    ALTER TABLE incidence DROP COLUMN Name, DROP COLUMN `Group`
"""
with connection.cursor() as cursor:
    cursor.execute(drop_column_query)
    
connection.close()

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

drop_column_query = """
    ALTER TABLE coverage DROP COLUMN `Group`, DROP COLUMN Name
"""
with connection.cursor() as cursor:
    cursor.execute(drop_column_query)
    
connection.close()

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

drop_column_query = """
    ALTER TABLE reported DROP COLUMN `Group`, DROP COLUMN Name
"""
with connection.cursor() as cursor:
    cursor.execute(drop_column_query)
    
connection.close()

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

drop_column_query = """
    ALTER TABLE reported DROP COLUMN Disease_Description
"""
with connection.cursor() as cursor:
    cursor.execute(drop_column_query)
    
connection.close()

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

drop_column_query = """
    ALTER TABLE incidence DROP COLUMN Disease_Description
"""
with connection.cursor() as cursor:
    cursor.execute(drop_column_query)
    
connection.close()

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

drop_column_query = """
    ALTER TABLE vacsch DROP COLUMN COUNTRYNAME, DROP COLUMN WHO_REGION
"""
with connection.cursor() as cursor:
    cursor.execute(drop_column_query)
    
connection.close()

# %%
connection.reconnect()

select_database_query = "USE WHO_Vaccination"

with connection.cursor() as cursor:
    cursor.execute(select_database_query)

drop_column_query = """
    ALTER TABLE vacintro DROP COLUMN COUNTRYNAME, DROP COLUMN WHO_REGION
"""
with connection.cursor() as cursor:
    cursor.execute(drop_column_query)
    
connection.close()
